# %% [markdown]
# # 机械分词

# %%
#正向最小
def forwardMin(s,dic,maxL):
    res_dic=[]
    i=0
    length=2
    while i<(len(s)):
        if s[i:i+length] in dic:
            res_dic.append(s[i:i+length])
            i+=length
            length=2
        elif length+1<=maxL:
            length+=1
        else:
            res_dic.append(s[i])
            i+=1
            length=2
    return res_dic

# %%
#正向最大
def forwardMax(s,dic,maxL):
    res_dic=[]
    i=0
    length=maxL
    while i<(len(s)):
        if s[i:min(len(s),i+length)] in dic:
            res_dic.append(s[i:min(len(s),i+length)])
            i+=length
            length=maxL
        elif length-1>=2:
            length-=1
        else:
            res_dic.append(s[i])
            i+=1
            length=maxL
    return res_dic

# %%
#逆向最小
def backwardMin(s,dic,maxL):
    res_dic=[]
    i=len(s)-1
    length=2
    while i>=0:
        if s[i-length+1:i+1] in dic:
            res_dic.insert(0,s[i-length+1:i+1])
            i-=length
            length=2
        elif length+1<=maxL:
            length+=1
        else:
            res_dic.insert(0,s[i])
            i-=1
            length=2
    return res_dic

# %%
#逆向最大
def backwardMax(s,dic,maxL):
    res_dic=[]
    i=len(s)-1
    length=maxL
    while i>=0:
        if s[max(0,i-length+1):i+1] in dic:
            res_dic.insert(0,s[max(0,i-length+1):i+1])
            i-=length
            length=maxL
        elif length-1>=2:
            length-=1
        else:
            res_dic.insert(0,s[i])
            i-=1
            length=maxL
    return res_dic

# %%
#load dictionary
dic=[]
maxL=0
for i in range(2):
    f = open('wordlist'+str(i)+'.txt','r', encoding='UTF-8')
    if f:
        line = f.readline()
        while line:
            if len(line)-1>maxL:
                maxL=len(line)-1
            dic.append(line[:-1])
            line = f.readline()
        f.close()
    else:
        print('Open file error!')
print(maxL)
print(len(dic))
print(dic[-100:-1])
# Out:
# 16
# 508682
# ['龈牙纤维', '龈牙结合部', '龈瓣', '龈纤维瘤病多毛综合征', '龈袋', '龈谷', '龋失补', '龋失补牙', '龋失补牙面', '龋病学', '龋齿', '龌龊', '龙三', '龙与地下城', '龙之峡谷', '龙争虎斗', '龙二', '龙五', '龙井', '龙井县', '龙井茶', '龙众', '龙体', '龙兄', '龙兄虎弟', '龙凤', '龙凤呈祥', '龙凤胎', '龙凤配', '龙凤饼', '龙华', '龙华工专', '龙南', '龙卷', '龙卷风', '龙口', '龙口夺食', '龙吟', '龙吟虎啸', '龙吼', '龙头', '龙头企业', '龙头老大', '龙套', '龙女', '龙子', '龙子龙女', '龙子龙孙', '龙宫', '龙山', '龙山区', '龙山县', '龙山寺', '龙山文化', '龙岗', '龙岛主', '龙岩', '龙岩市', '龙崎', '龙川', '龙川县', '龙州', '龙年', '龙年大吉', '龙床', '龙床快婿', '龙庭', '龙德邻', '龙文', '龙文五笔', '龙文输入通', '龙方', '龙枪', '龙枪编年史', '龙树', '龙楼凤阁', '龙江', '龙江县', '龙江路', '龙泉', '龙泉县', '龙泉驿区', '龙洞', '龙济光', '龙海', '龙海县', '龙涎', '龙涎香', '龙游', '龙游县', '龙游浅水遭虾戏', '龙溪', '龙潭', '龙潭虎穴', '龙灯', '龙烟铁矿', '龙爪槐', '龙牙星', '龙王']

# %%
s='我有80个朋友，我不喜欢第2个'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['我有', '8', '0', '个', '朋友', '，', '我不', '喜欢', '第', '2', '个']
# ['我有', '8', '0', '个', '朋友', '，', '我不', '喜欢', '第', '2', '个']
# ['我有', '8', '0', '个', '朋友', '，', '我不', '喜欢', '第', '2', '个']
# ['我有', '8', '0', '个', '朋友', '，', '我', '不喜欢', '第', '2', '个']

# %%
s='原子结合成分子'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['原子', '结合', '成分', '子']
# ['原子', '结合', '成分', '子']
# ['原子', '结', '合成', '分子']
# ['原子', '结', '合成', '分子']

# %%
s='我们一起来玩耍'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['我们', '一起', '来', '玩耍']
# ['我们', '一起来', '玩耍']
# ['我们', '一', '起来', '玩耍']
# ['我们', '一起来', '玩耍']

# %%
s='咬死猎人的狗'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['咬', '死', '猎人', '的', '狗']
# ['咬', '死', '猎人', '的', '狗']
# ['咬', '死', '猎', '人的', '狗']
# ['咬', '死', '猎', '人的', '狗']

# %%
s='张天昊大佬'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['张', '天', '昊', '大佬']
# ['张', '天', '昊', '大佬']
# ['张', '天', '昊', '大佬']
# ['张', '天', '昊', '大佬']

# %%
if '吴其平' in dic:
    dic.remove('吴其平')
s='吴其平常常写代码'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['吴', '其', '平常', '常', '写', '代码']
# ['吴', '其', '平常', '常', '写', '代码']
# ['吴', '其', '平', '常常', '写', '代码']
# ['吴', '其', '平', '常常', '写', '代码']

# %%
dic.append('吴其平')
s='吴其平常常写代码'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['吴其平', '常常', '写', '代码']
# ['吴其平', '常常', '写', '代码']
# ['吴其平', '常常', '写', '代码']
# ['吴其平', '常常', '写', '代码']

# %%
s='上海自来水来自海上'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['上海', '自来', '水来', '自', '海上']
# ['上海', '自来水', '来自', '海上']
# ['上海', '自', '来水', '来自', '海上']
# ['上海', '自来水', '来自', '海上']

# %%
s='结婚的和尚未结婚的'
print(forwardMin(s,dic,maxL))
print(forwardMax(s,dic,maxL))
print(backwardMin(s,dic,maxL))
print(backwardMax(s,dic,maxL))
# Out:
# ['结婚', '的', '和尚', '未结', '婚', '的']
# ['结婚', '的', '和尚', '未结', '婚', '的']
# ['结婚', '的', '和', '尚未', '结婚', '的']
# ['结婚', '的', '和', '尚未', '结婚', '的']

# %%
#load test sentences
test_list=[]
f = open('test.txt','r', encoding='UTF-8')
if f:
    line=f.readline()
    while line:
        test_list.append(line)
        line=f.readline()
    f.close()
else:
    print('Open file error!')

# %%
#test
for sentence in test_list:
    print(sentence)
    print(forwardMin(sentence[:-1],dic,maxL))
    print(forwardMax(sentence[:-1],dic,maxL))
    print(backwardMin(sentence[:-1],dic,maxL))
    print(backwardMax(sentence[:-1],dic,maxL))
    print('-----------------------------------------')
# Out:
# 研究生命科学
#
# ['研究', '生命', '科学']
# ['研究生', '命', '科学']
# ['研究', '生命', '科学']
# ['研究', '生命科学']
# -----------------------------------------
# 研究生命令本科生
#
# ['研究', '生命', '令', '本科', '生']
# ['研究生', '命令', '本科生']
# ['研究生', '命令', '本', '科生']
# ['研究', '生命令', '本科生']
# -----------------------------------------
# 我从马上下来
#
# ['我', '从', '马上', '下来']
# ['我', '从', '马上', '下来']
# ['我', '从', '马上', '下来']
# ['我', '从', '马上', '下来']
# -----------------------------------------
# 我马上下来
#
# ['我', '马上', '下来']
# ['我', '马上', '下来']
# ['我', '马上', '下来']
# ['我', '马上', '下来']
# -----------------------------------------
# 北京大学生喝进口红酒
#
# ['北京', '大学', '生', '喝进', '口红', '酒']
# ['北京大学', '生', '喝进', '口红', '酒']
# ['北京', '大', '学生', '喝', '进口', '红酒']
# ['北京', '大学生', '喝', '进口', '红酒']
# -----------------------------------------
# 在北京大学生活区喝进口红酒
#
# ['在', '北京', '大学', '生活', '区', '喝进', '口红', '酒']
# ['在', '北京大学', '生活区', '喝进', '口红', '酒']
# ['在', '北京', '大学', '生活区', '喝', '进口', '红酒']
# ['在', '北京大学', '生活区', '喝', '进口', '红酒']
# -----------------------------------------
# 从小学电脑
#
# ['从小', '学', '电脑']
# ['从小', '学', '电脑']
# ['从', '小学', '电脑']
# ['从', '小学', '电脑']
# -----------------------------------------
# 从小学毕业
#
# ['从小', '学', '毕业']
# ['从小', '学', '毕业']
# ['从', '小学', '毕业']
# ['从', '小学', '毕业']
# -----------------------------------------
# 美军中将竟公然说
#
# ['美军', '中将', '竟', '公然', '说']
# ['美军', '中将', '竟', '公然', '说']
# ['美军', '中将', '竟', '公然', '说']
# ['美军', '中将', '竟', '公然', '说']
# -----------------------------------------
# 新建地铁中将禁止商业摊点
#
# ['新建', '地铁', '中将', '禁止', '商业', '摊点']
# ['新建', '地铁', '中将', '禁止', '商业', '摊点']
# ['新建', '地铁', '中将', '禁止', '商业', '摊点']
# ['新建', '地铁', '中将', '禁止', '商业', '摊点']
# -----------------------------------------
# 这块地面积还真不小
#
# ['这块', '地面', '积', '还真', '不小']
# ['这块', '地面', '积', '还真', '不小']
# ['这块', '地', '面积', '还真', '不小']
# ['这块', '地', '面积', '还真', '不小']
# -----------------------------------------
# 地面积了厚厚的雪
#
# ['地面', '积', '了', '厚厚', '的', '雪']
# ['地面', '积', '了', '厚厚的', '雪']
# ['地', '面积', '了', '厚', '厚的', '雪']
# ['地', '面积', '了', '厚厚的', '雪']
# -----------------------------------------
# 让我们以爱心和平等来对待动物
#
# ['让我', '们', '以', '爱心', '和平', '等', '来', '对待', '动物']
# ['让我们', '以', '爱心', '和平', '等', '来', '对待', '动物']
# ['让', '我们', '以', '爱心', '和', '平等', '来', '对待', '动物']
# ['让我们', '以', '爱心', '和', '平等', '来', '对待', '动物']
# -----------------------------------------
# 阿美首脑会议将讨论巴以和平等问题
#
# ['阿美', '首脑', '会议', '将', '讨论', '巴以', '和平', '等', '问题']
# ['阿美', '首脑会议', '将', '讨论', '巴以', '和平', '等', '问题']
# ['阿美', '首脑', '会议', '将', '讨论', '巴以', '和', '平等', '问题']
# ['阿美', '首脑会议', '将', '讨论', '巴以', '和', '平等', '问题']
# -----------------------------------------
# 锌合金把手的相关求购信息
#
# ['锌合金', '把手', '的', '相关', '求购', '信息']
# ['锌合金', '把手', '的', '相关', '求购', '信息']
# ['锌', '合金', '把手', '的', '相关', '求购', '信息']
# ['锌合金', '把手', '的', '相关', '求购', '信息']
# -----------------------------------------
# 别把手伸进别人的口袋里
#
# ['别把', '手', '伸进', '别人', '的', '口袋', '里']
# ['别把', '手', '伸进', '别人', '的', '口袋', '里']
# ['别', '把手', '伸进', '别', '人的', '口袋', '里']
# ['别', '把手', '伸进', '别', '人的', '口袋', '里']
# -----------------------------------------
# 将信息技术应用于教学实践
#
# ['将', '信息', '技术', '应用', '于', '教学', '实践']
# ['将', '信息技术', '应用于', '教学', '实践']
# ['将', '信息', '技术', '应', '用于', '教学', '实践']
# ['将', '信息技术', '应用于', '教学', '实践']
# -----------------------------------------
# 信息技术应用于教学中的哪个方面
#
# ['信息', '技术', '应用', '于', '教学', '中的', '哪个', '方面']
# ['信息技术', '应用于', '教学', '中的', '哪个', '方面']
# ['信息', '技术', '应', '用于', '教学', '中的', '哪个', '方面']
# ['信息技术', '应用于', '教学', '中的', '哪个', '方面']
# -----------------------------------------
# 上级解除了他的职务
#
# ['上级', '解除', '了', '他的', '职务']
# ['上级', '解除', '了', '他的', '职务']
# ['上级', '解', '除了', '他的', '职务']
# ['上级', '解', '除了', '他的', '职务']
# -----------------------------------------
# 方程的解除了零以外还有…
#
# ['方程', '的', '解除', '了', '零', '以外', '还有', '…']
# ['方程', '的', '解除', '了', '零', '以外', '还有', '…']
# ['方程', '的', '解', '除了', '零', '以外', '还有', '…']
# ['方程', '的', '解', '除了', '零', '以外', '还有', '…']
# -----------------------------------------
# 我们一起去故宫
#
# ['我们', '一起', '去', '故宫']
# ['我们', '一起去', '故宫']
# ['我们', '一起去', '故宫']
# ['我们', '一起去', '故宫']
# -----------------------------------------
# 一起恶性交通事故
#
# ['一起', '恶性', '交通', '事故']
# ['一起', '恶性', '交通事故']
# ['一起', '恶性', '交通', '事故']
# ['一起', '恶性', '交通事故']
# -----------------------------------------
# 我不想吃东西
#
# ['我不', '想', '吃东西']
# ['我不', '想', '吃东西']
# ['我', '不想', '吃', '东西']
# ['我', '不想', '吃东西']
# -----------------------------------------
# 你就不想想
#
# ['你就', '不想', '想']
# ['你就', '不想想']
# ['你', '就不', '想想']
# ['你就', '不想想']
# -----------------------------------------
# 各国有企业相继倒闭
#
# ['各国', '有', '企业', '相继', '倒闭']
# ['各国', '有', '企业', '相继', '倒闭']
# ['各', '国有', '企业', '相继', '倒闭']
# ['各', '国有企业', '相继', '倒闭']
# -----------------------------------------
# 各国有各国的困难
#
# ['各国', '有', '各国', '的', '困难']
# ['各国', '有', '各国', '的', '困难']
# ['各', '国有', '各国', '的', '困难']
# ['各', '国有', '各国', '的', '困难']
# -----------------------------------------
# 老人家身体不错
#
# ['老人', '家', '身体', '不错']
# ['老人家', '身体', '不错']
# ['老', '人家', '身体', '不错']
# ['老人家', '身体', '不错']
# -----------------------------------------
# 老人家中很干净
#
# ['老人', '家中', '很', '干净']
# ['老人家', '中', '很', '干净']
# ['老人', '家中', '很', '干净']
# ['老人', '家中', '很', '干净']
# -----------------------------------------
# 和服务必归还
#
# ['和服', '务必', '归还']
# ['和服', '务必', '归还']
# ['和服', '务必', '归还']
# ['和服', '务必', '归还']
# -----------------------------------------
# 技术和服务
#
# ['技术', '和服', '务']
# ['技术', '和服', '务']
# ['技术', '和', '服务']
# ['技术', '和', '服务']
# -----------------------------------------
# 他站起身
#
# ['他', '站起', '身']
# ['他', '站起', '身']
# ['他', '站', '起身']
# ['他', '站', '起身']
# -----------------------------------------
# 他起身去北京
#
# ['他', '起身', '去', '北京']
# ['他', '起身', '去', '北京']
# ['他', '起身', '去', '北京']
# ['他', '起身', '去', '北京']
# -----------------------------------------
# 问题的确定
#
# ['问题', '的确', '定']
# ['问题', '的确', '定']
# ['问题', '的', '确定']
# ['问题', '的', '确定']
# -----------------------------------------
# 这的确定不下来
#
# ['这', '的确', '定', '不下', '来']
# ['这', '的确', '定', '不下来']
# ['这', '的', '确定', '不', '下来']
# ['这', '的', '确定', '不下来']
# -----------------------------------------
# 结合成分
#
# ['结合', '成分']
# ['结合', '成分']
# ['结合', '成分']
# ['结合', '成分']
# -----------------------------------------
# 为人民工作
#
# ['为人', '民工', '作']
# ['为人', '民工', '作']
# ['为', '人民', '工作']
# ['为', '人民', '工作']
# -----------------------------------------
# 中国产品质量
#
# ['中国', '产品', '质量']
# ['中国产品', '质量']
# ['中国', '产品', '质量']
# ['中国', '产品质量']
# -----------------------------------------
# 原子结合成分子时
#
# ['原子', '结合', '成分', '子时']
# ['原子', '结合', '成分', '子时']
# ['原子', '结合', '成分', '子时']
# ['原子', '结合', '成分', '子时']
# -----------------------------------------
# 部分居民生活水平
#
# ['部分', '居民', '生活', '水平']
# ['部分', '居民', '生活水平']
# ['部分', '居民', '生活', '水平']
# ['部分', '居民', '生活水平']
# -----------------------------------------
# 治理解放大道路面积水
#
# ['治理', '解放', '大道', '路面', '积水']
# ['治理', '解放', '大道', '路面', '积水']
# ['治理', '解放', '大道', '路面', '积水']
# ['治理', '解放', '大道', '路面', '积水']
# -----------------------------------------
# 这样的人才能经受住考验
#
# ['这样', '的人', '才能', '经受', '住', '考验']
# ['这样', '的人', '才能', '经受', '住', '考验']
# ['这样', '的人', '才能', '经受', '住', '考验']
# ['这样', '的人', '才能', '经受', '住', '考验']
# -----------------------------------------
# 他俩儿谈恋爱是从头年元月开始的
#
# ['他俩', '儿', '谈恋爱', '是从', '头年', '元月', '开始', '的']
# ['他俩', '儿', '谈恋爱', '是从', '头年', '元月', '开始', '的']
# ['他俩', '儿', '谈', '恋爱', '是从', '头年', '元月', '开始', '的']
# ['他俩', '儿', '谈恋爱', '是从', '头年', '元月', '开始', '的']
# -----------------------------------------
# 在这些企业中国有企业有十个
#
# ['在这', '些', '企业', '中国', '有', '企业', '有', '十', '个']
# ['在这', '些', '企业', '中国', '有', '企业', '有', '十', '个']
# ['在', '这些', '企业', '中', '国有', '企业', '有', '十', '个']
# ['在', '这些', '企业', '中', '国有企业', '有', '十', '个']
# -----------------------------------------
# 结婚的和尚未结婚的
# ['结婚', '的', '和尚', '未结', '婚']
# ['结婚', '的', '和尚', '未结', '婚']
# ['结婚', '的', '和', '尚未', '结婚']
# ['结婚', '的', '和', '尚未', '结婚']
# -----------------------------------------
